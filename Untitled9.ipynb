# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
zmt=pd.read_csv('C:/Users/goswami/Jupyter Notebook/Zomato data .csv')
def handlerate(x):
    x=str(x).split('/')
    x=x[0]
    return float(x)
zmt['rate']=zmt['rate'].apply(handlerate)
zmt.head()
sns.countplot(x=zmt['listed_in(type)'])
# Out:
# <Axes: xlabel='listed_in(type)', ylabel='count'>

# %%
a=zmt.groupby('listed_in(type)')['votes'].sum
result=pd.DataFrame({'votes':[a]})
plt.plot(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a=zmt.groupby('listed_in(type)')['votes'].sum
#       2 result=pd.DataFrame({'votes':[a]})
# ----> 3 plt.plot(result)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1726, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...
